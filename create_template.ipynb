# %%
import pandas as pd

columns = [
    "provider",
    "model",
    "group_id",
    "prompt1_run_id",
    "prompt2_run_id",
    "persona_id",
    "persona_name",
    "profile_details",
    "name",
    "age",
    "gender",
    "personality_traits",
    "domain_of_work",
    "years_of_experience",
    "location",
    "education_level",
    "devices_technologies_use",
    "reasons",
    "phishing_susceptible",
    "reason_category",
    "bias_flag",
    "bias_type",
    "interpretation_notes",
    "updated_persona_changed",
    "change_type"
]

df = pd.DataFrame(columns=columns)
df.to_csv("assignment2_persona_dataset_template.csv", index=False, encoding="utf-8-sig")

print("Template created successfully.")
print("Number of columns:", len(df.columns))
print(df.columns.tolist())
